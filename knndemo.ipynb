# %%
import numpy as np

# %%
import knn

# %%
knn.create_dataset()
# Out:
# (array([[ 1. ,  1.1],
#         [ 1. ,  1. ],
#         [ 0. ,  0. ],
#         [ 0. ,  0.1]]), ['A', 'A', 'B', 'B'])

# %%
dataset, groups = knn.create_dataset()

# %%
groups
# Out:
# ['A', 'A', 'B', 'B']

# %%
dataset
# Out:
# array([[ 1. ,  1.1],
#        [ 1. ,  1. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0.1]])

# %%
filename = 'data/ch02/datingTestSet.txt'
f = open(filename, 'r')
f.readlines()
# Out:
# ['40920\t8.326976\t0.953952\tlargeDoses\n',
#  '14488\t7.153469\t1.673904\tsmallDoses\n',
#  '26052\t1.441871\t0.805124\tdidntLike\n',
#  '75136\t13.147394\t0.428964\tdidntLike\n',
#  '38344\t1.669788\t0.134296\tdidntLike\n',
#  '72993\t10.141740\t1.032955\tdidntLike\n',
#  '35948\t6.830792\t1.213192\tlargeDoses\n',
#  '42666\t13.276369\t0.543880\tlargeDoses\n',
#  '67497\t8.631577\t0.749278\tdidntLike\n',
#  '35483\t12.273169\t1.508053\tlargeDoses\n',
#  '50242\t3.723498\t0.831917\tdidntLike\n',
#  '63275\t8.385879\t1.669485\tdidntLike\n',
#  '5569\t4.875435\t0.728658\tsmallDoses\n',
#  '51052\t4.680098\t0.625224\tdidntLike\n',
#  '77372\t15.299570\t0.331351\tdidntLike\n',
#  '43673\t1.889461\t0.191283\tdidntLike\n',
#  '61364\t7.516754\t1.269164\tdidntLike\n',
#  '69673\t14.239195\t0.261333\tdidntLike\n',
#  '15669\t0.000000\t1.250185\tsmallDoses\n',
#  '28488\t10.528555\t1.304844\tlargeDoses\n',
#  '6487\t3.540265\t0.822483\tsmallDoses\n',
# ...

# %%
import pandas as pd

# %%
matrix = pd.read_csv(filename, sep='\s+', header=None)
matrix
# Out:
#          0          1         2           3
# 0    40920   8.326976  0.953952  largeDoses
# 1    14488   7.153469  1.673904  smallDoses
# 2    26052   1.441871  0.805124   didntLike
# 3    75136  13.147394  0.428964   didntLike
# 4    38344   1.669788  0.134296   didntLike
# 5    72993  10.141740  1.032955   didntLike
# 6    35948   6.830792  1.213192  largeDoses
# 7    42666  13.276369  0.543880  largeDoses
# 8    67497   8.631577  0.749278   didntLike
# 9    35483  12.273169  1.508053  largeDoses
# 10   50242   3.723498  0.831917   didntLike
# 11   63275   8.385879  1.669485   didntLike
# 12    5569   4.875435  0.728658  smallDoses
# 13   51052   4.680098  0.625224   didntLike
# 14   77372  15.299570  0.331351   didntLike
# 15   43673   1.889461  0.191283   didntLike
# 16   61364   7.516754  1.269164   didntLike
# 17   69673  14.239195  0.261333   didntLike
# 18   15669   0.000000  1.250185  smallDoses
# 19   28488  10.528555  1.304844  largeDoses
# ...

# %%
type(matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
list(matrix[3].unique())
# Out:
# ['largeDoses', 'smallDoses', 'didntLike']

# %%
reload(knn)
knn.load_dataset(filename)
# Out:
# (         0          1         2           3
#  0    40920   8.326976  0.953952  largeDoses
#  1    14488   7.153469  1.673904  smallDoses
#  2    26052   1.441871  0.805124   didntLike
#  3    75136  13.147394  0.428964   didntLike
#  4    38344   1.669788  0.134296   didntLike
#  5    72993  10.141740  1.032955   didntLike
#  6    35948   6.830792  1.213192  largeDoses
#  7    42666  13.276369  0.543880  largeDoses
#  8    67497   8.631577  0.749278   didntLike
#  9    35483  12.273169  1.508053  largeDoses
#  10   50242   3.723498  0.831917   didntLike
#  11   63275   8.385879  1.669485   didntLike
#  12    5569   4.875435  0.728658  smallDoses
#  13   51052   4.680098  0.625224   didntLike
#  14   77372  15.299570  0.331351   didntLike
#  15   43673   1.889461  0.191283   didntLike
#  16   61364   7.516754  1.269164   didntLike
#  17   69673  14.239195  0.261333   didntLike
#  18   15669   0.000000  1.250185  smallDoses
#  19   28488  10.528555  1.304844  largeDoses
# ...

# %%
group, labels = knn.load_dataset(filename)

# %%
import matplotlib
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(group[1], group[2])
plt.show()

# %%
labels = group[3].as_matrix()
labels
# Out:
# array(['largeDoses', 'smallDoses', 'didntLike', 'didntLike', 'didntLike',
#        'didntLike', 'largeDoses', 'largeDoses', 'didntLike', 'largeDoses',
#        'didntLike', 'didntLike', 'smallDoses', 'didntLike', 'didntLike',
#        'didntLike', 'didntLike', 'didntLike', 'smallDoses', 'largeDoses',
#        'smallDoses', 'didntLike', 'smallDoses', 'largeDoses', 'smallDoses',
#        'largeDoses', 'smallDoses', 'largeDoses', 'smallDoses', 'didntLike',
#        'largeDoses', 'didntLike', 'largeDoses', 'didntLike', 'smallDoses',
#        'didntLike', 'didntLike', 'smallDoses', 'largeDoses', 'largeDoses',
#        'didntLike', 'smallDoses', 'largeDoses', 'largeDoses', 'largeDoses',
#        'didntLike', 'didntLike', 'didntLike', 'didntLike', 'smallDoses',
#        'smallDoses', 'didntLike', 'largeDoses', 'smallDoses', 'smallDoses',
#        'smallDoses', 'smallDoses', 'largeDoses', 'didntLike', 'smallDoses',
# ...

# %%
flyermiles = group[0].as_matrix()
videogames = group[1].as_matrix()
icecream = group[2].as_matrix()

# %%
dataset = group.as_matrix()
dataset
# Out:
# array([[40920, 8.326976, 0.953952, 'largeDoses'],
#        [14488, 7.153469, 1.673904, 'smallDoses'],
#        [26052, 1.441871, 0.805124, 'didntLike'],
#        ...,
#        [26575, 10.650102, 0.866627, 'largeDoses'],
#        [48111, 9.134528, 0.7280449999999999, 'largeDoses'],
#        [43757, 7.882600999999999, 1.332446, 'largeDoses']], dtype=object)

# %%
dataset.min(0)
# Out:
# array([0, 0.0, 0.0011560000000000001, 'didntLike'], dtype=object)

# %%
flyermiles.min(), videogames.min(), icecream.min()
# Out:
# (0, 0.0, 0.0011560000000000001)

# %%
dataset.max()
# Out:
# 'smallDoses'

# %%
dataset.max(0)
# Out:
# array([91273, 20.919349, 1.6955169999999997, 'smallDoses'], dtype=object)

# %%
flyermiles.max(), videogames.max(), icecream.max()
# Out:
# (91273, 20.919349, 1.6955169999999997)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-31fa223750d7> in <module>()
# ----> 1 ranges = (dataset.min(0) - dataset.max(0))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
