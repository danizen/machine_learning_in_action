# %%
import matplotlib.pyplot as plt
import dectre

# %%
reload(dectre)
# Out:
# <module 'dectre' from 'dectre.py'>

# %%
atree = dectre.retrieveTree(0)

# %%
atree
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}

# %%
dectre.createPlot(atree)

# %%
tree2 = dectre.retrieveTree(1)
dectre.createPlot(tree2)

# %%
tree2
# Out:
# {'no surfacing': {0: 'no',
#   1: {'flippers': {0: {'head': {0: 'no', 1: 'yes'}}, 1: 'no'}}}}

# %%
labels = ['no surfacing', 'flippers']

# %%
dectre.classify(atree, labels, [1,0])
# Out:
# 'no'

# %%
dectre.classify(atree, labels, [1,1])
# Out:
# 'yes'
